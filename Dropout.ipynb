# %% [markdown]
# # Dropout
# Dropout [1] is a technique for regularizing neural networks by randomly setting some features to zero during the forward pass. In this exercise you will implement a dropout layer and modify your fully-connected network to optionally use dropout.
#
# [1] Geoffrey E. Hinton et al, "Improving neural networks by preventing co-adaptation of feature detectors", arXiv 2012

# %%
# As usual, a bit of setup

import time
import numpy as np
import matplotlib.pyplot as plt
from deeplearning.classifiers.fc_net import *
from deeplearning.data_utils import get_CIFAR10_data
from deeplearning.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from deeplearning.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in data.items():
    print ('%s: ' % k, v.shape)
# Out:
# deeplearning/datasets/cifar-10-batches-py/data_batch_1
# deeplearning/datasets/cifar-10-batches-py/data_batch_2
# deeplearning/datasets/cifar-10-batches-py/data_batch_3
# deeplearning/datasets/cifar-10-batches-py/data_batch_4
# deeplearning/datasets/cifar-10-batches-py/data_batch_5
# deeplearning/datasets/cifar-10-batches-py/test_batch
# X_train:  (49000, 3, 32, 32)
# y_train:  (49000,)
# X_val:  (1000, 3, 32, 32)
# y_val:  (1000,)
# X_test:  (1000, 3, 32, 32)
# y_test:  (1000,)

# %% [markdown]
# # Dropout forward pass
# In the file `deeplearning/layers.py`, implement the forward pass for (inverted) dropout. Since dropout behaves differently during training and testing, make sure to implement the operation for both modes. Input means should be approximately the same as the output means at both train/test time.
#
# Once you have done so, run the cell below to test your implementation.

# %%
x = np.random.randn(500, 500) + 10

for p in [0.3, 0.6, 0.75]:
    out, _ = dropout_forward(x, {'mode': 'train', 'p': p})
    out_test, _ = dropout_forward(x, {'mode': 'test', 'p': p})

    print ('Running tests with p = ', p)
    print ('Mean of input: ', x.mean())
    print ('Mean of train-time output: ', out.mean())
    print ('Mean of test-time output: ', out_test.mean())
    print ('Fraction of train-time output set to zero: ', (out == 0).mean())
    print ('Fraction of test-time output set to zero: ', (out_test == 0).mean())
    print
# Out:
# Running tests with p =  0.3
# Mean of input:  9.998646875547923
# Mean of train-time output:  9.989221138153109
# Mean of test-time output:  9.998646875547923
# Fraction of train-time output set to zero:  0.700276
# Fraction of test-time output set to zero:  0.0
# Running tests with p =  0.6
# Mean of input:  9.998646875547923
# Mean of train-time output:  10.002179398396777
# Mean of test-time output:  9.998646875547923
# Fraction of train-time output set to zero:  0.399784
# Fraction of test-time output set to zero:  0.0
# Running tests with p =  0.75
# Mean of input:  9.998646875547923
# Mean of train-time output:  10.006049876901196
# Mean of test-time output:  9.998646875547923
# Fraction of train-time output set to zero:  0.249408
# Fraction of test-time output set to zero:  0.0

# %% [markdown]
# # Dropout backward pass
# In the file `deeplearning/layers.py`, implement the backward pass for dropout. After doing so, run the following cell to numerically gradient-check your implementation.

# %%
x = np.random.randn(10, 10) + 10
dout = np.random.randn(*x.shape)

dropout_param = {'mode': 'train', 'p': 0.75, 'seed': 123}
out, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)
dx_num = eval_numerical_gradient_array(lambda xx: dropout_forward(xx, dropout_param)[0], x, dout)

print ('dx relative error: ', rel_error(dx, dx_num))
# Out:
# dx relative error:  6.333781393238382e-11

# %% [markdown]
# # Fully-connected nets with Dropout
# In the file `deeplearning/classifiers/fc_net.py`, modify your implementation to use dropout. Specificially, if the constructor the the net receives a nonzero value for the `dropout` parameter, then the net should add dropout immediately after every ReLU nonlinearity. After doing so, run the following to numerically gradient-check your implementation.

# %%
N, D, H1, H2, C = 2, 15, 20, 30, 10
np.random.seed(123)
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for dropout in [0, 0.25, 0.5]:
    print ('Running check with dropout = ', dropout)
    model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dtype=np.float64,
                            dropout=dropout, seed=123)
    
    loss, grads = model.loss(X, y)
    print ('Initial loss: ', loss)

    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print ('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
    print
# Out:
# Running check with dropout =  0
# number of layers: 2
# False
# Initial loss:  3.3756419705083793
# W1 relative error: 1.00e+00
# W2 relative error: 9.05e-01
# b1 relative error: 1.00e+00
# b2 relative error: 9.05e-01
# Running check with dropout =  0.25
# number of layers: 2
# True
# ..Initial loss:  3.4057562572643043
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................W1 relative error: 1.00e+00
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................W2 relative error: 9.05e-01
# ..................................................................................b1 relative error: 1.00e+00
# ..........................................................................................................................b2 relative error: 9.05e-01
# Running check with dropout =  0.5
# number of layers: 2
# True
# ..Initial loss:  3.317158757052969
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................W1 relative error: 1.00e+00
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................W2 relative error: 9.05e-01
# ..................................................................................b1 relative error: 1.00e+00
# ..........................................................................................................................b2 relative error: 9.05e-01

# %% [markdown]
# # Regularization experiment
# As an experiment, we will train a pair of two-layer networks on 500 training examples: one will use no dropout, and one will use a dropout probability of 0.75. We will then visualize the training and validation accuracies of the two networks over time.

# %%
# Train two identical nets, one with dropout and one without

num_train = 500
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}
dropout_choices = [0, 0.75]
for dropout in dropout_choices:
    model = FullyConnectedNet([500], dropout=dropout)
    print (dropout)

    solver = Solver(model, small_data,
                  num_epochs=20, batch_size=25,
                  #num_epochs=25, batch_size=100,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 5e-4,
                  },
                  verbose=True, print_every=250)
    solver.train()
    solvers[dropout] = solver
# Out:
# number of layers: 1
# False
# 0
# batch 25 , lr_decay 1.0
# iters 20 , samples 500
# (Iteration 1 / 1000) loss: 76.417867 lr: 0.000500
# (Epoch 0 / 50) train acc: 0.048000; val_acc: 0.039000
# (Epoch 1 / 50) train acc: 0.236000; val_acc: 0.168000
# (Epoch 2 / 50) train acc: 0.336000; val_acc: 0.200000
# (Epoch 3 / 50) train acc: 0.388000; val_acc: 0.237000
# (Epoch 4 / 50) train acc: 0.460000; val_acc: 0.219000
# (Epoch 5 / 50) train acc: 0.498000; val_acc: 0.198000
# (Iteration 101 / 1000) loss: 40.970974 lr: 0.000500
# (Epoch 6 / 50) train acc: 0.554000; val_acc: 0.241000
# (Epoch 7 / 50) train acc: 0.586000; val_acc: 0.241000
# (Epoch 8 / 50) train acc: 0.628000; val_acc: 0.253000
# (Epoch 9 / 50) train acc: 0.614000; val_acc: 0.224000
# (Epoch 10 / 50) train acc: 0.666000; val_acc: 0.236000
# (Iteration 201 / 1000) loss: 51.367688 lr: 0.000500
# (Epoch 11 / 50) train acc: 0.670000; val_acc: 0.225000
# (Epoch 12 / 50) train acc: 0.698000; val_acc: 0.222000
# (Epoch 13 / 50) train acc: 0.646000; val_acc: 0.207000
# (Epoch 14 / 50) train acc: 0.698000; val_acc: 0.216000
# (Epoch 15 / 50) train acc: 0.720000; val_acc: 0.251000
# (Iteration 301 / 1000) loss: 4.660842 lr: 0.000500
# (Epoch 16 / 50) train acc: 0.738000; val_acc: 0.242000
# (Epoch 17 / 50) train acc: 0.716000; val_acc: 0.220000
# (Epoch 18 / 50) train acc: 0.700000; val_acc: 0.219000
# (Epoch 19 / 50) train acc: 0.728000; val_acc: 0.218000
# (Epoch 20 / 50) train acc: 0.748000; val_acc: 0.235000
# (Iteration 401 / 1000) loss: 14.633833 lr: 0.000500
# (Epoch 21 / 50) train acc: 0.738000; val_acc: 0.212000
# (Epoch 22 / 50) train acc: 0.758000; val_acc: 0.232000
# (Epoch 23 / 50) train acc: 0.774000; val_acc: 0.236000
# (Epoch 24 / 50) train acc: 0.760000; val_acc: 0.229000
# (Epoch 25 / 50) train acc: 0.772000; val_acc: 0.223000
# (Iteration 501 / 1000) loss: 12.396776 lr: 0.000500
# (Epoch 26 / 50) train acc: 0.790000; val_acc: 0.229000
# (Epoch 27 / 50) train acc: 0.806000; val_acc: 0.233000
# (Epoch 28 / 50) train acc: 0.810000; val_acc: 0.228000
# (Epoch 29 / 50) train acc: 0.806000; val_acc: 0.227000
# (Epoch 30 / 50) train acc: 0.836000; val_acc: 0.244000
# (Iteration 601 / 1000) loss: 5.877249 lr: 0.000500
# (Epoch 31 / 50) train acc: 0.846000; val_acc: 0.244000
# (Epoch 32 / 50) train acc: 0.838000; val_acc: 0.240000
# (Epoch 33 / 50) train acc: 0.822000; val_acc: 0.238000
# ...................(Epoch 21 / 50) train acc: 0.698000; val_acc: 0.191000
# ....................(Epoch 22 / 50) train acc: 0.718000; val_acc: 0.217000
# ....................(Epoch 23 / 50) train acc: 0.704000; val_acc: 0.192000
# ....................(Epoch 24 / 50) train acc: 0.742000; val_acc: 0.201000
# ....................(Epoch 25 / 50) train acc: 0.736000; val_acc: 0.199000
# .(Iteration 501 / 1000) loss: 42.269300 lr: 0.000500
# ...................(Epoch 26 / 50) train acc: 0.710000; val_acc: 0.203000
# ....................(Epoch 27 / 50) train acc: 0.710000; val_acc: 0.182000
# ....................(Epoch 28 / 50) train acc: 0.778000; val_acc: 0.212000
# ....................(Epoch 29 / 50) train acc: 0.762000; val_acc: 0.207000
# ....................(Epoch 30 / 50) train acc: 0.742000; val_acc: 0.197000
# .(Iteration 601 / 1000) loss: 31.136461 lr: 0.000500
# ...................(Epoch 31 / 50) train acc: 0.724000; val_acc: 0.187000
# ....................(Epoch 32 / 50) train acc: 0.688000; val_acc: 0.184000
# ....................(Epoch 33 / 50) train acc: 0.758000; val_acc: 0.196000
# ....................(Epoch 34 / 50) train acc: 0.752000; val_acc: 0.197000
# ....................(Epoch 35 / 50) train acc: 0.774000; val_acc: 0.192000
# .(Iteration 701 / 1000) loss: 53.778942 lr: 0.000500
# ...................(Epoch 36 / 50) train acc: 0.744000; val_acc: 0.179000
# ....................(Epoch 37 / 50) train acc: 0.730000; val_acc: 0.178000
# ....................(Epoch 38 / 50) train acc: 0.798000; val_acc: 0.202000
# ....................(Epoch 39 / 50) train acc: 0.794000; val_acc: 0.192000
# ....................(Epoch 40 / 50) train acc: 0.804000; val_acc: 0.197000
# .(Iteration 801 / 1000) loss: 77.909135 lr: 0.000500
# ...................(Epoch 41 / 50) train acc: 0.808000; val_acc: 0.196000
# ....................(Epoch 42 / 50) train acc: 0.812000; val_acc: 0.195000
# ....................(Epoch 43 / 50) train acc: 0.796000; val_acc: 0.195000
# ....................(Epoch 44 / 50) train acc: 0.824000; val_acc: 0.204000
# ....................(Epoch 45 / 50) train acc: 0.818000; val_acc: 0.204000
# .(Iteration 901 / 1000) loss: 10.469591 lr: 0.000500
# ...................(Epoch 46 / 50) train acc: 0.816000; val_acc: 0.203000
# ....................(Epoch 47 / 50) train acc: 0.812000; val_acc: 0.204000
# ....................(Epoch 48 / 50) train acc: 0.776000; val_acc: 0.184000
# ....................(Epoch 49 / 50) train acc: 0.802000; val_acc: 0.179000
# ....................(Epoch 50 / 50) train acc: 0.800000; val_acc: 0.182000

# %%
# Plot train and validation accuracies of the two models
loss = []
train_accs = []
val_accs = []
for dropout in dropout_choices:
    solver = solvers[dropout]
    loss.append(solver.loss_history[-1])
    train_accs.append(solver.train_acc_history[-1])
    val_accs.append(solver.val_acc_history[-1])
    solver.record_histories_as_npz('submission_logs/dropout_regularization_experiment_p{}.npz'.format(dropout))

plt.subplot(3, 1, 1)
for dropout in dropout_choices:
    plt.plot(solvers[dropout].train_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Train accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')
  
plt.subplot(3, 1, 2)
for dropout in dropout_choices:
    plt.plot(solvers[dropout].val_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.subplot(3, 1, 3)
for dropout in dropout_choices:
    plt.plot(solvers[dropout].loss_history, 'x', label='%.2f dropout' % dropout)
plt.title('loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # Question
# Explain what you see in this experiment. What does it suggest about dropout?

# %% [markdown]
# # Answer
